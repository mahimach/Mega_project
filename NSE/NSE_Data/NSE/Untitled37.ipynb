# %%
pip install yfinance
# Out:
# ...
#
# ...

# %%
import yfinance as yf
import pandas as pd
data = yf.download("RELIANCE.NS", start="2015-01-01", end="2024-06-30")
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2015-01-01   405.186554   407.792389   403.975037   405.917999   381.517334
# 2015-01-02   406.009430   409.643921   404.272217   404.843658   380.507599
# 2015-01-05   404.592224   407.289520   399.609100   400.409149   376.339569
# 2015-01-06   397.734741   399.106232   380.362396   382.236786   359.259583
# 2015-01-07   382.693970   392.614471   382.648254   390.557220   367.079926
# ...                 ...          ...          ...          ...          ...
# 2024-06-24  2891.050049  2899.000000  2875.000000  2882.949951  2873.198242
# 2024-06-25  2886.000000  2911.850098  2882.000000  2908.300049  2898.462646
# 2024-06-26  2892.100098  3037.949951  2890.250000  3028.050049  3017.807617
# 2024-06-27  3027.500000  3075.000000  3012.000000  3061.100098  3050.745850
# ...

# %%
equity_details = pd.read_csv("EQUI.csv")
equity_details
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 Microns Limited      EQ
# 1     21STCENMGM  21st Century Management Services Limited      BE
# 2         360ONE                       360 ONE WAM LIMITED      EQ
# 3      3IINFOLTD                       3i Infotech Limited      EQ
# 4        3MINDIA                          3M India Limited      EQ
# ...          ...                                       ...     ...
# 1990        ZOTA                  Zota Health Care LImited      EQ
# 1991       ZUARI              Zuari Agro Chemicals Limited      EQ
# 1992    ZUARIIND                  ZUARI INDUSTRIES LIMITED      EQ
# 1993   ZYDUSLIFE                Zydus Lifesciences Limited      EQ
# 1994   ZYDUSWELL                    Zydus Wellness Limited      EQ
#
#       DATE OF LISTING   PAID UP VALUE   MARKET LOT   ISIN NUMBER   FACE VALUE
# 0         06-OCT-2008               5            1  INE144J01027            5
# ...

# %%
equity_details.SYMBOL
# Out:
# 0        20MICRONS
# 1       21STCENMGM
# 2           360ONE
# 3        3IINFOLTD
# 4          3MINDIA
#            ...
# 1990          ZOTA
# 1991         ZUARI
# 1992      ZUARIIND
# 1993     ZYDUSLIFE
# 1994     ZYDUSWELL
# Name: SYMBOL, Length: 1995, dtype: object

# %%
for name in equity_details.SYMBOL:
  try:
    data = yf.download(f'{name}.NS', start="2015-01-01", end="2024-06-30")
    data.to_csv(name+".csv")
  except Exception as e:
    print(f'{name}.NS',e)
    continue

    print(name)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...
